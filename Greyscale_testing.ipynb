# %%
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/ryantenbarge/Desktop/LeWagon_Notes_in_Jupyter/sandbox'

# %%
val_data_path = os.path.join(current_dir, '..', '..', 'H1-No23-572', 'val', '15.png')
val_data_path
# Out:
# '/Users/ryantenbarge/Desktop/LeWagon_Notes_in_Jupyter/sandbox/../../H1-No23-572/val/15.png'

# %%
my_image = cv2.imread(val_data_path)
type(my_image)
# Out:
# numpy.ndarray

# %%
my_image.shape
# Out:
# (572, 572, 3)

# %%
masking_color = (255, 0, 255)

# %%
plt.imshow(np.all(my_image == [255, 0, 255], axis=-1)*1, cmap='gray')

# %%
plt.imshow(new_image, cmap='grey')

# %%
google_image_path = os.path.join(current_dir, '..', '..', 'Screenshot 2024-02-10 at 10.43.56 AM.png')
google_image_path
# Out:
# '/Users/ryantenbarge/Desktop/LeWagon_Notes_in_Jupyter/sandbox/../../Screenshot 2024-02-10 at 10.43.56 AM.png'

# %%
gim = Image.open(google_image_path)
desired_size = (572, 572)
resized_gim = gim.resize(desired_size)
resized_gim
# Out:
# <PIL.Image.Image image mode=RGBA size=572x572>
